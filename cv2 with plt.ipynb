# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\rohit\anaconda3\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\rohit\anaconda3\lib\site-packages (from opencv-python) (1.24.3)

# %%
import cv2

# %%
#read an image

img = cv2.imread("image_folder/city.jpg")

newImg = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(img)
plt.show()

plt.imshow(newImg)
plt.show()

# %%
print(img)
# Out:
# [[[104  49  28]
#   [102  48  25]
#   [102  50  27]
#   ...
#   [225 213 207]
#   [225 213 207]
#   [226 214 208]]
#
#  [[106  49  28]
#   [102  48  25]
#   [104  50  27]
#   ...
#   [208 196 190]
#   [208 196 190]
#   [208 196 190]]
#
#  [[106  48  29]
#   [105  48  27]
#   [106  49  27]
#   ...
#   [212 200 194]
#   [212 200 194]
#   [211 199 193]]
#
#  ...
#
#  [[189 133 116]
#   [173 121 105]
#   [176 124 111]
#   ...
#   [122  62  46]
#   [107  60  38]
#   [120  63  41]]
#
#  [[191 133 114]
#   [175 121 104]
#   [178 126 110]
#   ...
#   [119  63  44]
#   [111  61  39]
#   [120  63  42]]
#
#  [[201 142 122]
#   [187 131 112]
#   [187 135 118]
#   ...
#   [122  65  44]
#   [121  62  43]
#   [116  60  43]]]
